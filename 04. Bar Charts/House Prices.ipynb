# %%
# %pylab inline
import matplotlib.pyplot
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Checking Linearity

# %%
house_sizes = [1300, 1400, 1600, 1900, 2100, 2300]
prices = [88000, 72000, 94000, 86000, 112000, 98000]

# %%
plt.plot(house_sizes, prices)

# %% [markdown]
# # Interpolation

# %%
sqr_ft_2200 = ((112000 - 98000) / 2) + 98000
sqr_ft_2200
# Out:
# 105000.0

# %% [markdown]
# # Grouping Data

# %%
plt.bar(house_sizes, prices, width=1/1.5, color='blue')
# Out:
# <Container object of 6 artists>

# %% [markdown]
# # Histograms

# %%
incomes = [132754, 137192, 122177, 147121, 143000, 126010, 129200,
           124312, 128132]

# %%
plt.hist(incomes, bins=3)
# Out:
# (array([ 5.,  2.,  2.]),
#  array([ 122177.        ,  130491.66666667,  138806.33333333,  147121.        ]),
#  <a list of 3 Patch objects>)

# %% [markdown]
# # Age Distribution

# %%
ages = [21, 17, 9, 27, 35, 4, 12, 12, 32, 14, 9, 38, 19, 22, 14, 21, 8, 3,
       31, 15, 33, 29]

# %%
plt.hist(ages, bins=4)
# Out:
# (array([ 5.,  7.,  5.,  5.]),
#  array([  3.  ,  11.75,  20.5 ,  29.25,  38.  ]),
#  <a list of 4 Patch objects>)
